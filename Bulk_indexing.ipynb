# %%
from elasticsearch import Elasticsearch, helpers
import pandas as pd
import json
import time
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
# URL of the CSV file
csv_url = "https://data.cityofnewyork.us/resource/h9gi-nx95.csv"

# %%
# Load the CSV file directly from the URL
df = pd.read_csv(csv_url)

# %%
df.head()
# Out:
#                 crash_date crash_time   borough  zip_code   latitude  \
# 0  2021-09-11T00:00:00.000       2:39       NaN       NaN        NaN
# 1  2022-03-26T00:00:00.000      11:45       NaN       NaN        NaN
# 2  2022-06-29T00:00:00.000       6:55       NaN       NaN        NaN
# 3  2021-09-11T00:00:00.000       9:35  BROOKLYN   11208.0  40.667202
# 4  2021-12-14T00:00:00.000       8:13  BROOKLYN   11233.0  40.683304
#
#    longitude                        location           on_street_name  \
# 0        NaN                             NaN    WHITESTONE EXPRESSWAY
# 1        NaN                             NaN  QUEENSBORO BRIDGE UPPER
# 2        NaN                             NaN       THROGS NECK BRIDGE
# 3 -73.866500    \n,  \n(40.667202, -73.8665)                      NaN
# 4 -73.917274  \n,  \n(40.683304, -73.917274)          SARATOGA AVENUE
#
#   off_street_name        cross_street_name  ...  \
# 0       20 AVENUE                      NaN  ...
# 1             NaN                      NaN  ...
# 2             NaN                      NaN  ...
# 3             NaN  1211      LORING AVENUE  ...
# 4  DECATUR STREET                      NaN  ...
#
#    contributing_factor_vehicle_2  contributing_factor_vehicle_3  \
# 0                    Unspecified                            NaN
# 1                            NaN                            NaN
# 2                    Unspecified                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    contributing_factor_vehicle_4  contributing_factor_vehicle_5  collision_id  \
# 0                            NaN                            NaN       4455765
# 1                            NaN                            NaN       4513547
# 2                            NaN                            NaN       4541903
# 3                            NaN                            NaN       4456314
# 4                            NaN                            NaN       4486609
#
#    vehicle_type_code1  vehicle_type_code2  vehicle_type_code_3  \
# 0               Sedan               Sedan                  NaN
# 1               Sedan                 NaN                  NaN
# 2               Sedan       Pick-up Truck                  NaN
# 3               Sedan                 NaN                  NaN
# 4                 NaN                 NaN                  NaN
#
#   vehicle_type_code_4 vehicle_type_code_5
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
# Select a subset of columns for simplicity
df = df[['collision_id', 'crash_date', 'crash_time', 'borough', 'latitude', 'longitude', 'on_street_name', 'number_of_persons_injured', 'number_of_persons_killed']]

# %%
# Convert the crash_date to datetime format
df['crash_date'] = pd.to_datetime(df['crash_date'])

# %%
json_str = df.to_json(orient='records', date_format='iso')
# print(json_str)

# %%
# Save it as a JSON file
df.to_json('nyc_traffic_incidents.json', orient='records', date_format = 'iso', lines=True)

# %%
df.head()
# Out:
#    collision_id crash_date crash_time   borough   latitude  longitude  \
# 0       4455765 2021-09-11       2:39       NaN        NaN        NaN
# 1       4513547 2022-03-26      11:45       NaN        NaN        NaN
# 2       4541903 2022-06-29       6:55       NaN        NaN        NaN
# 3       4456314 2021-09-11       9:35  BROOKLYN  40.667202 -73.866500
# 4       4486609 2021-12-14       8:13  BROOKLYN  40.683304 -73.917274
#
#             on_street_name  number_of_persons_injured  \
# 0    WHITESTONE EXPRESSWAY                          2
# 1  QUEENSBORO BRIDGE UPPER                          1
# 2       THROGS NECK BRIDGE                          0
# 3                      NaN                          0
# 4          SARATOGA AVENUE                          0
#
#    number_of_persons_killed
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0

# %%
INDEX_BODY = {
    "mappings": {
        "properties": {
            "collision_id": {"type": "long"},
            "crash_date": {
                "type": "date",
                "format": "yyyy-MM-dd'T'HH:mm:ss.SSS||yyyy-MM-dd'T'HH:mm:ss.SSSZ||yyyy-MM-dd"
            },
            "crash_time": {"type": "text"},
            "borough": {"type": "text"},
            "latitude": {"type": "float"},
            "longitude": {"type": "float"},
            "on_street_name": {"type": "text"},
            "number_of_persons_injured": {"type": "integer"},
            "number_of_persons_killed": {"type": "integer"}
        }
    },
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    }
}

# %%
es = Elasticsearch(
    [{'host': 'localhost', 'port': 9200, 'scheme': 'http'}],
    basic_auth=('elastic', '123456')
)

# %%
def preprocess_data(file_path):
    processed_data = []
    with open(file_path, 'r') as f:
        for line in f:
            doc = json.loads(line)
            # Remove fields with NaN values
            doc_clean = {k: v for k, v in doc.items() if pd.notna(v)}
            processed_data.append(doc_clean)
    return processed_data

# %%
def create_index(index):
    try:
        cr = es.indices.create(index=index, body=INDEX_BODY)
        print(f"Index '{index}' created successfully.")
    except Exception as e:
        print(f"Index creation error: {e}")

# %%
def insert_data_by_bulk(data, index):
    actions = [
        {
            '_index': index,
            '_source': doc
        }
        for doc in data
    ]
    
    try:
        success, failed = helpers.bulk(es, actions, stats_only=False, raise_on_error=False)
        print(f"Bulk indexing result: {success} succeeded, {len(failed)} failed")
        for error in failed:
            print(error)
    except Exception as e:
        print("Indexing Error:", e)

# %%
# Function to insert data by bulk
def insert_data_by_bulk_1(data, index):
    actions = [
        {
            "_index": index,
            "_source": doc
        }
        for doc in data
    ]

    try:
        # Use helpers.bulk to insert data in bulk
        response = helpers.bulk(es, actions)
        print(f"Indexed {response[0]} documents")
    except Exception as e:
        print(f"Error bulk indexing data: {e}")

# %%
def search_data_by_bulk(index):
    # res_data = es.search(index=index, body={"from": 0, "size": 10, "query": {"match": {'Type': 'Accident'}}})
    res_data = es.search(index=index, body={"from": 0, "size": 10, "query": {"match_all" : {} }})
    print("Search result:", res_data)
    return res_data

# %%
def search_data_by_bulk_1(index):
    query = {
        "query": {
            "range": {
                "number_of_persons_injured": {
                    "gt": 2  # Greater than 2
                }
            }
        }
    }
    res_data = es.search(index=index, body=query)
    print("Search result:", res_data)
    return res_data['hits']

# %%
index = "sales_index_new5"
# create_index(index)

index_new = es.indices.create(index=index, body= INDEX_BODY)

# %%
data = preprocess_data('nyc_traffic_incidents.json')

# print(data)

# %%
insert_data_by_bulk(data, index)
# Out:
# Bulk indexing result: 1000 succeeded, 0 failed

# %%
if __name__ == "__main__":
    # index = "sales_index_3"
    # create_index(index)
    # data = preprocess_data(json_str)
    # insert_data_by_bulk_1(data, index_name)
    search_data_by_bulk_1(index)
# Out:
# Search result: {'took': 6, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 23, 'relation': 'eq'}, 'max_score': 1.0, 'hits': [{'_index': 'sales_index_new5', '_id': 'I2WAKZABII3UBHuKmeYO', '_score': 1.0, '_source': {'collision_id': 4486991, 'crash_date': '2021-12-14T00:00:00.000', 'crash_time': '20:03', 'borough': 'BROOKLYN', 'latitude': 40.65068, 'longitude': -73.95881, 'number_of_persons_injured': 4, 'number_of_persons_killed': 0}}, {'_index': 'sales_index_new5', '_id': 'JGWAKZABII3UBHuKmeYO', '_score': 1.0, '_source': {'collision_id': 4486284, 'crash_date': '2021-12-14T00:00:00.000', 'crash_time': '1:28', 'on_street_name': 'MEEKER AVENUE', 'number_of_persons_injured': 3, 'number_of_persons_killed': 0}}, {'_index': 'sales_index_new5', '_id': 'ZWWAKZABII3UBHuKmeYO', '_score': 1.0, '_source': {'collision_id': 4485523, 'crash_date': '2021-12-08T00:00:00.000', 'crash_time': '19:30', 'on_street_name': 'OCEAN PARKWAY', 'number_of_persons_injured': 4, 'number_of_persons_killed': 0}}, {'_index': 'sales_index_new5', '_id': 'f2WAKZABII3UBHuKmeYO', '_score': 1.0, '_source': {'collision_id': 4514323, 'crash_date': '2022-03-10T00:00:00.000', 'crash_time': '8:30', 'borough': 'BROOKLYN', 'latitude': 40.676403, 'longitude': -73.96287, 'on_street_name': 'PROSPECT PLACE', 'number_of_persons_injured': 4, 'number_of_persons_killed': 0}}, {'_index': 'sales_index_new5', '_id': 'pWWAKZABII3UBHuKmeYO', '_score': 1.0, '_source': {'collision_id': 4513803, 'crash_date': '2022-03-26T00:00:00.000', 'crash_time': '17:54', 'borough': 'BROOKLYN', 'latitude': 40.645718, 'longitude': -73.95002, 'number_of_persons_injured': 4, 'number_of_persons_killed': 0}}, {'_index': 'sales_index_new5', '_id': 'pGWAKZABII3UBHuKmecP', '_score': 1.0, '_source': {'collision_id': 4455827, 'crash_date': '2021-09-11T00:00:00.000', 'crash_time': '0:20', 'latitude': 40.76555, 'longitude': -73.83911, 'on_street_name': 'VAN WYCK EXPWY', 'number_of_persons_injured': 3, 'number_of_persons_killed': 0}}, {'_index': 'sales_index_new5', '_id': 'wWWAKZABII3UBHuKmecP', '_score': 1.0, '_source': {'collision_id': 4457021, 'crash_date': '2021-09-05T00:00:00.000', 'crash_time': '21:18', 'borough': 'QUEENS', 'latitude': 40.69674, 'longitude': -73.76292, 'on_street_name': '114 DRIVE', 'number_of_persons_injured': 5, 'number_of_persons_killed': 0}}, {'_index': 'sales_index_new5', '_id': 'w2WAKZABII3UBHuKmecP', '_score': 1.0, '_source': {'collision_id': 4456043, 'crash_date': '2021-09-11T00:00:00.000', 'crash_time': '11:30', 'latitude': 40.83232, 'longitude': -73.87395, 'on_street_name': 'BRONX RIVER PARKWAY', 'number_of_persons_injured': 3, 'number_of_persons_killed': 0}}, {'_index': 'sales_index_new5', '_id': '2mWAKZABII3UBHuKmecP', '_score': 1.0, '_source': {'collision_id': 4405244, 'crash_date': '2021-04-06T00:00:00.000', 'crash_time': '22:58', 'borough': 'STATEN ISLAND', 'latitude': 40.526894, 'longitude': -74.16728, 'on_street_name': 'BARCLAY AVENUE', 'number_of_persons_injured': 7, 'number_of_persons_killed': 0}}, {'_index': 'sales_index_new5', '_id': '62WAKZABII3UBHuKmecP', '_score': 1.0, '_source': {'collision_id': 4408038, 'crash_date': '2021-04-16T00:00:00.000', 'crash_time': '23:20', 'borough': 'BROOKLYN', 'latitude': 40.649788, 'longitude': -73.9622, 'on_street_name': 'EAST 19 STREET', 'number_of_persons_injured': 3, 'number_of_persons_killed': 0}}]}}

# %%
es = Elasticsearch(
    [{'host': 'localhost', 'port': 9200, 'scheme': 'http'}],
    basic_auth=('elastic', '123456')
)

# %%
df = pd.read_csv("C:\\Users\\Sridevi\\Downloads\\supermarket_sales - Sheet1.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
data = df[:10]


data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
required_columns = ['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
                    'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date']

# %%
df = df[required_columns]

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-05-01
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-08-03
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480        NaT
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-08-02

# %%
# Convert date column to the correct format using .loc
df.loc[:, 'Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y', errors='coerce')
# Out:
# C:\Users\Sridevi\AppData\Local\Temp\ipykernel_34228\2518040418.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y', errors='coerce')
# C:\Users\Sridevi\AppData\Local\Temp\ipykernel_34228\2518040418.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y', errors='coerce')

# %%
index_name = "sales_index2"

mapping = {
    "mappings": {
        "properties": {
            "Invoice ID": {
                "type": "text",
                "fields": {
                    "keyword": {
                        "type": "keyword",
                        "ignore_above": 256
                    }
                }
            },
            "Branch": {
                "type": "text",
                "fields": {
                    "keyword": {
                        "type": "keyword",
                        "ignore_above": 256
                    }
                }
            },
            "City": {
                "type": "text",
                "fields": {
                    "keyword": {
                        "type": "keyword",
                        "ignore_above": 256
                    }
                }
            },
            "Customer type": {
                "type": "text",
                "fields": {
                    "keyword": {
                        "type": "keyword",
                        "ignore_above": 256
                    }
                }
            },
            "Gender": {
                "type": "text",
                "fields": {
                    "keyword": {
                        "type": "keyword",
                        "ignore_above": 256
                    }
                }
            },
            "Product line": {
                "type": "text",
                "fields": {
                    "keyword": {
                        "type": "keyword",
                        "ignore_above": 256
                    }
                }
            },
            "Unit price": {
                "type": "float"
            },
            "Quantity": {
                "type": "integer"
            },
            "Tax 5%": {
                "type": "float"
            },
            "Total": {
                "type": "float"
            },
            "Date": {
                "type": "date",
                "format": "d/M/yyyy"
            }
        }
    }
}

# %%
# Create the index with the updated mapping
es.indices.create(index=index_name, body=mapping, ignore=400)
# Out:
# C:\Users\Sridevi\AppData\Local\Temp\ipykernel_34228\4026189890.py:2: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   es.indices.create(index=index_name, body=mapping, ignore=400)
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'sales_index2'})

# %%
# Function to generate actions for bulk indexing
def generate_actions(df, index_name):
    for _, row in df.iterrows():
        yield {
            "_index": index_name,
            "_source": row.dropna().to_dict(),  # Drop any NaN values to avoid indexing issues
        }

# Generate actions
actions = list(generate_actions(df, index_name))

# %%
print(actions)
# Out:
# [{'_index': 'sales_index2', '_source': {'Invoice ID': '750-67-8428', 'Branch': 'A', 'City': 'Yangon', 'Customer type': 'Member', 'Gender': 'Female', 'Product line': 'Health and beauty', 'Unit price': 74.69, 'Quantity': 7, 'Tax 5%': 26.1415, 'Total': 548.9715, 'Date': Timestamp('2019-05-01 00:00:00')}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '226-31-3081', 'Branch': 'C', 'City': 'Naypyitaw', 'Customer type': 'Normal', 'Gender': 'Female', 'Product line': 'Electronic accessories', 'Unit price': 15.28, 'Quantity': 5, 'Tax 5%': 3.82, 'Total': 80.22, 'Date': Timestamp('2019-08-03 00:00:00')}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '631-41-3108', 'Branch': 'A', 'City': 'Yangon', 'Customer type': 'Normal', 'Gender': 'Male', 'Product line': 'Home and lifestyle', 'Unit price': 46.33, 'Quantity': 7, 'Tax 5%': 16.2155, 'Total': 340.5255, 'Date': Timestamp('2019-03-03 00:00:00')}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '123-19-1176', 'Branch': 'A', 'City': 'Yangon', 'Customer type': 'Member', 'Gender': 'Male', 'Product line': 'Health and beauty', 'Unit price': 58.22, 'Quantity': 8, 'Tax 5%': 23.288, 'Total': 489.048}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '373-73-7910', 'Branch': 'A', 'City': 'Yangon', 'Customer type': 'Normal', 'Gender': 'Male', 'Product line': 'Sports and travel', 'Unit price': 86.31, 'Quantity': 7, 'Tax 5%': 30.2085, 'Total': 634.3785, 'Date': Timestamp('2019-08-02 00:00:00')}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '699-14-3026', 'Branch': 'C', 'City': 'Naypyitaw', 'Customer type': 'Normal', 'Gender': 'Male', 'Product line': 'Electronic accessories', 'Unit price': 85.39, 'Quantity': 7, 'Tax 5%': 29.8865, 'Total': 627.6165}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '355-53-5943', 'Branch': 'A', 'City': 'Yangon', 'Customer type': 'Member', 'Gender': 'Female', 'Product line': 'Electronic accessories', 'Unit price': 68.84, 'Quantity': 6, 'Tax 5%': 20.652, 'Total': 433.692}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '315-22-5665', 'Branch': 'C', 'City': 'Naypyitaw', 'Customer type': 'Normal', 'Gender': 'Female', 'Product line': 'Home and lifestyle', 'Unit price': 73.56, 'Quantity': 10, 'Tax 5%': 36.78, 'Total': 772.38}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '665-32-9167', 'Branch': 'A', 'City': 'Yangon', 'Customer type': 'Member', 'Gender': 'Female', 'Product line': 'Health and beauty', 'Unit price': 36.26, 'Quantity': 2, 'Tax 5%': 3.626, 'Total': 76.146, 'Date': Timestamp('2019-10-01 00:00:00')}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '692-92-5582', 'Branch': 'B', 'City': 'Mandalay', 'Customer type': 'Member', 'Gender': 'Female', 'Product line': 'Food and beverages', 'Unit price': 54.84, 'Quantity': 3, 'Tax 5%': 8.226, 'Total': 172.746}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '351-62-0822', 'Branch': 'B', 'City': 'Mandalay', 'Customer type': 'Member', 'Gender': 'Female', 'Product line': 'Fashion accessories', 'Unit price': 14.48, 'Quantity': 4, 'Tax 5%': 2.896, 'Total': 60.816, 'Date': Timestamp('2019-06-02 00:00:00')}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '529-56-3974', 'Branch': 'B', 'City': 'Mandalay', 'Customer type': 'Member', 'Gender': 'Male', 'Product line': 'Electronic accessories', 'Unit price': 25.51, 'Quantity': 4, 'Tax 5%': 5.102, 'Total': 107.142, 'Date': Timestamp('2019-09-03 00:00:00')}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '365-64-0515', 'Branch': 'A', 'City': 'Yangon', 'Customer type': 'Normal', 'Gender': 'Female', 'Product line': 'Electronic accessories', 'Unit price': 46.95, 'Quantity': 5, 'Tax 5%': 11.7375, 'Total': 246.4875, 'Date': Timestamp('2019-12-02 00:00:00')}}, {'_index': 'sales_index2', '_source': {'Invoice ID': '252-56-2699', 'Branch': 'A', 'City': 'Yangon', 'Customer type': 'Normal', 'Gender': 'Male', 'Product line': 'Food and beverages', 'Unit price': 43.19, 'Quantity': 10, 'Tax 5%': 21.595, 'Total': 453.495, 'Date ...

# %%
# Perform bulk indexing with error handling
try:
    helpers.bulk(es, actions)
# except exceptions.BulkIndexError as e:
#     # Print detailed error information
#     print(f"Bulk indexing failed for {len(e.errors)} documents.")
#     for error in e.errors:
#         print(error)
# Out:
#   Cell In[25], line 8
#     #         print(error)
#                           ^
# SyntaxError: unexpected EOF while parsing

# %%
helpers.bulk(es, actions)
# Out:
# ---------------------------------------------------------------------------
# BulkIndexError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 helpers.bulk(es, actions)
#
# File c:\python\python39\lib\site-packages\elasticsearch\helpers\actions.py:521, in bulk(client, actions, stats_only, ignore_status, *args, **kwargs)
#     519 # make streaming_bulk yield successful results so we can count them
#     520 kwargs["yield_ok"] = True
# --> 521 for ok, item in streaming_bulk(
#     522     client, actions, ignore_status=ignore_status, *args, **kwargs  # type: ignore[misc]
#     523 ):
#     524     # go through request-response pairs and detect failures
#     525     if not ok:
#     526         if not stats_only:
#
# File c:\python\python39\lib\site-packages\elasticsearch\helpers\actions.py:436, in streaming_bulk(client, actions, chunk_size, max_chunk_bytes, raise_on_error, expand_action_callback, raise_on_exception, max_retries, initial_backoff, max_backoff, yield_ok, ignore_status, *args, **kwargs)
#     433     time.sleep(min(max_backoff, initial_backoff * 2 ** (attempt - 1)))
#     435 try:
# --> 436     for data, (ok, info) in zip(
#     437         bulk_data,
#     438         _process_bulk_chunk(
#     439             client,
#     440             bulk_actions,
#     441             bulk_data,
#     442             raise_on_exception,
#     443             raise_on_error,
#     444             ignore_status,
#     445             *args,
#     446             **kwargs,
#     447         ),
#     448     ):
#     449         if not ok:
#     450             action, info = info.popitem()
#
# File c:\python\python39\lib\site-packages\elasticsearch\helpers\actions.py:355, in _process_bulk_chunk(client, bulk_actions, bulk_data, raise_on_exception, raise_on_error, ignore_status, *args, **kwargs)
#     348 else:
#     349     gen = _process_bulk_chunk_success(
#     350         resp=resp.body,
#     351         bulk_data=bulk_data,
#     352         ignore_status=ignore_status,
#     353         raise_on_error=raise_on_error,
#     354     )
# --> 355 yield from gen
#
# File c:\python\python39\lib\site-packages\elasticsearch\helpers\actions.py:274, in _process_bulk_chunk_success(resp, bulk_data, ignore_status, raise_on_error)
#     271         yield ok, {op_type: item}
#     273 if errors:
# --> 274     raise BulkIndexError(f"{len(errors)} document(s) failed to index.", errors)
#
# BulkIndexError: 229 document(s) failed to index.

# %%
es.indices.refresh(index=index_name)
# Out:
# ObjectApiResponse({'_shards': {'total': 2, 'successful': 1, 'failed': 0}})

# %%
# Count the documents in the index
doc_count = es.count(index=index_name)['count']
print(f'Document count in {index_name}: {doc_count}')
# Out:
# Document count in sales_index2: 271
